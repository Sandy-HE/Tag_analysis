# %%
from gensim.models import Word2Vec
import pandas as pd

# %%
df = pd.read_csv("allprunedtags_emo_only.csv", index_col=0)

# %%
df.head()
# Out:
#                                    prunedtag
# track_id
# TRAAAAK128F9318786                       NaN
# TRAAAAW128F429D538                       NaN
# TRAAABD128F429CF47  love;love;love;love;love
# TRAAADJ128F4287B47                       NaN
# TRAAADZ128F9348C2E                       NaN

# %%
df.dropna(subset = ["prunedtag"], inplace=True)

# %%
df.shape
# Out:
# (126926, 1)

# %%
temp2 = df['prunedtag'].apply(lambda x: x.split(";"))

# %%
terms_list = temp2.tolist()

# %%
model = Word2Vec(terms_list, 
                min_count=2,   # Ignore words that appear less than this
                size=128,      # Dimensionality of word embeddings
                workers=2,     # Number of processors (parallelisation)
                window=5,      # Context window for words during training
                iter=10,       # Number of epochs training over corpus
                sg=1)
#sg = 1

# %%
wordvec = model[model.wv.vocab]
# Out:
# C:\Users\winte\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
wordvec_df=pd.DataFrame(data=wordvec)

# %%
wordvec_df['term']=list(model.wv.vocab)

# %%
wordvec_df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.152273  0.149239  0.103013  0.070312 -0.009078  0.041785 -0.064606
# 1   -0.381544 -0.336349  0.361252  0.171010 -0.258006  0.064054 -0.471965
# 2    0.050320 -0.213624  0.594798  0.189127 -0.100215  0.282999  0.182719
# 3    0.310872  0.004910  0.194885 -0.041442  0.172350 -0.207321 -0.108039
# 4    0.033227 -0.067269  0.265399  0.219534  0.013286 -0.504205  0.175593
# ..        ...       ...       ...       ...       ...       ...       ...
# 119  0.166109  0.507709  0.892711  0.508772  0.370448  0.474922  0.166861
# 120 -0.449438 -0.214590  0.223084  1.130248 -0.574095 -0.499019 -0.002357
# 121  0.281208  0.233708 -0.296280 -0.774415  0.033266 -0.190645  0.046211
# 122 -0.534923  0.657860 -0.032287 -0.198693  0.353127 -0.565013  0.147053
# 123 -1.026679  0.397380 -0.080607  0.063871  0.615620 -0.224029 -0.142953
#
#             7         8         9  ...       119       120       121  \
# 0    0.146203 -0.363260 -0.131689  ... -0.319827 -0.527455  0.147337
# 1    0.232126 -0.314641 -0.352969  ...  0.181988 -0.027743 -0.039378
# 2    0.453174 -0.129803 -0.123164  ... -0.007122 -0.565990 -0.492609
# 3    0.089106 -0.079600 -0.629340  ... -0.008862 -0.031358  0.088972
# 4    0.008345 -0.057613 -0.775644  ... -0.168167 -0.179132 -0.125319
# ..        ...       ...       ...  ...       ...       ...       ...
# 119  0.098516 -0.211361 -0.528821  ... -0.396098  0.040347  0.096410
# 120  0.015427  0.378751 -0.379729  ... -0.114784 -0.323698  0.064924
# 121  0.526675  0.109419 -0.122993  ...  0.029249 -0.032249  0.391445
# 122 -0.207030  0.240470 -0.604890  ...  0.460510  0.479540 -0.488357
# 123 -0.550281  0.941906 -0.326743  ...  0.206049 -0.315614  0.902996
#
#           122       123       124       125       126       127       term
# 0   -0.220964  0.196941 -0.266429  0.009959 -0.002434  0.174856       love
# 1    0.125876 -0.379295 -0.285392 -0.164475 -0.476789 -0.104310      chill
# 2    0.011983  0.352852 -0.079040 -0.179829 -0.046028 -0.021028   chillout
# 3   -0.385524 -0.281432  0.270536 -0.152926  0.065590  0.388929     mellow
# 4   -0.185797  0.053183 -0.027969 -0.084947 -0.174202 -0.011057      relax
# ..        ...       ...       ...       ...       ...       ...        ...
# 119  0.020424 -0.370672  0.220487 -0.283482 -0.528749  0.364766   tranquil
# 120 -0.016843  0.091851  0.644740 -0.315773 -0.017144  0.414846       lust
# 121  0.580424 -0.816085 -0.335093 -0.424672 -0.048329  0.163030    soaring
# 122 -0.385314  0.564539  0.398061  0.314026 -0.177638 -0.012682  desperate
# 123 -0.744624  0.364623 -0.433197 -0.221915 -0.805050 -0.555331       open
#
# [124 rows x 129 columns]

# %%
wordvec_df.to_csv('phrase_emo_only_sg_D128.csv', index=False)
